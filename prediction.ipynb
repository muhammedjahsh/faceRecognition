# %%
from faceRecognition import faceRecognitionPipeline
import cv2

# %%
img,pred_dicr = faceRecognitionPipeline("./test_images/getty_test.jpg")

# %%
cv2.namedWindow("Predicted image", cv2.WINDOW_NORMAL)
cv2.imshow("Predicted image",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Real Time Gender Classification

# %%
cap = cv2.VideoCapture("./test_images/video.mp4")
while True:
    ret,frame = cap.read()
    if ret ==False:
        break
    pred_img,pred_dict = faceRecognitionPipeline(frame,path=False)
    cv2.namedWindow("prediction", cv2.WINDOW_NORMAL)  # Enables resizing

    cv2.imshow("prediction",pred_img)
    if cv2.waitKey(1) == ord("q"):
        break
cap.release()
cv2.destroyAllWindows()
